# %%
import pandas as pd
from plotly.offline import init_notebook_mode, iplot
from plotly.graph_objs import *

init_notebook_mode(connected=True)         # initiate notebook for offline plot

df = pd.read_csv("../output/fort.21", sep='\s+', header=None).values
dfr = pd.read_csv("../output/fort.22", sep='\s+', header=None).values
dfxp = pd.read_csv("../output/fort.23", sep='\s+', header=None).values


n = 128                                    # number of coordinate steps
nt = 10                                   # maximum number of time steps
mod = 1                                   # to show each mod-th time point if needed 
trace = []
xf = []
yf = []
tf = []
for l in range(nt): 
    if not l%mod:
        xf.append(df[l*n:(l + 1)*n, 1])
        yf.append(df[l*n:(l + 1)*n, 2])
        tf.append(df[l*n:l*n + 1, 0])

for l in range(len(xf)):
    trace.append(Scatter(x = xf[l],y = yf[l],name = str(tf[l]).strip('[]')))
    
data = Data(trace)
fig = Figure(data)

fig.update_layout(
    title={
        'text': "Absolute value of the wave function",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title={
        'text': 'coordinate'
    },
    yaxis_title={
        'text': 'abs(Ψ)'
    }
)

iplot(fig)               # use plotly.offline.iplot for offline plot
#iplot(fig, image='svg', filename='fig_abs_wf', image_width=1280, image_height=780)

tracer = []
xfr = []
yfr = []
tfr = []
for l in range(nt): 
    if not l%mod:
        xfr.append(dfr[l*n:(l + 1)*n, 1])
        yfr.append(dfr[l*n:(l + 1)*n, 2])
        tfr.append(dfr[l*n:l*n + 1, 0])

for l in range(len(xfr)):
    tracer.append(Scatter(x = xfr[l],y = yfr[l],name = str(tfr[l]).strip('[]')))
    
datar = Data(tracer)
figr = Figure(datar)

figr.update_layout(
    title={
        'text': "Real value of the wave function",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title={
        'text': 'coordinate'
    },
    yaxis_title={
        'text': 'Re(Ψ)'
    }
)
iplot(figr)    # use plotly.offline.iplot for offline plot
#iplot(figr, image='svg', filename='fig_real_wf', image_width=1280, image_height=780)

tracem = []

namem = ["<x>", "<x^2>", "<p>", "<p^2>"]
    
for l in range(1,5):
    tracem.append(Scatter(x = dfxp[:, 0],y = dfxp[:, l],name = namem[l-1]))
    
datam = Data(tracem)
figm = Figure(datam)

figm.update_layout(
    title={
        'text': "Expectation values",
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    xaxis_title={
        'text': 'time'
    },
    yaxis_title={
        'text': '<A>'
    }
)

iplot(figm)    # use plotly.offline.iplot for offline plot
#iplot(figm, image='svg', filename='fig_real_m', image_width=1280, image_height=780)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1be1be66-4a7e-40e5-9407-fa8262728d0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1be1be66-4a7e-40e5-9407-fa8262728d0c")) {                    Plotly.newPlot(                        "1be1be66-4a7e-40e5-9407-fa8262728d0c",                        [{"name": "0.314159", "type": "scatter", "x": [-12.7, -12.5, -12.3, -12.1, -11.9, -11.7, -11.5, -11.3, -11.1, -10.9, -10.7, -10.5, -10.3, -10.1, -9.9, -9.7, -9.5, -9.3, -9.1, -8.9, -8.7, -8.5, -8.3, -8.1, -7.9, -7.7, -7.5, -7.3, -7.1, -6.9, -6.7, -6.5, -6.3, -6.1, -5.9, -5.7, -5.5, -5.3, -5.1, -4.9, -4.7, -4.5, -4.3, -4.1, -3.9, -3.7, -3.5, -3.3, -3.1, -2.9, -2.7, -2.5, -2.3, -2.1, -1.9, -1.7, -1.5, -1.3, -1.1, -0.9, -0.7, -0.5, -0.3, -0.1, 0.1, 0.3, 0.5, 0.7, 0.9, 1.1, 1.3, 1.5, 1.7, 1.9, 2